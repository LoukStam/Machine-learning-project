# %%
# imports
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_dir = Path("data")

kwargs_read_csv = dict()

filename = 'cc-est2023-agesex-56.csv'
filepath = Path(data_dir, filename)

df_data = pd.read_csv(filepath, **kwargs_read_csv)

# %%
df_data
# Out:
#      SUMLEV  STATE  COUNTY   STNAME        CTYNAME  YEAR  POPESTIMATE  \
# 0        50     56       1  Wyoming  Albany County     1        37069
# 1        50     56       1  Wyoming  Albany County     2        37112
# 2        50     56       1  Wyoming  Albany County     3        37854
# 3        50     56       1  Wyoming  Albany County     4        38178
# 4        50     56       1  Wyoming  Albany County     5        38257
# ..      ...    ...     ...      ...            ...   ...          ...
# 110      50     56      45  Wyoming  Weston County     1         6838
# 111      50     56      45  Wyoming  Weston County     2         6816
# 112      50     56      45  Wyoming  Weston County     3         6746
# 113      50     56      45  Wyoming  Weston County     4         6858
# 114      50     56      45  Wyoming  Weston County     5         6808
#
#      POPEST_MALE  POPEST_FEM  UNDER5_TOT  ...  AGE7579_FEM  AGE8084_TOT  \
# ...
