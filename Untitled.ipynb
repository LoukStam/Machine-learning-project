# %%
from typing import Tuple

import numpy as np
import pandas as pd

import xgboost as xgb


def make_categorical(
    n_samples: int, n_features: int, n_categories: int, onehot: bool
) -> Tuple[pd.DataFrame, pd.Series]:
    """Make some random data for demo."""
    rng = np.random.RandomState(1994)

    pd_dict = {}
    for i in range(n_features + 1):
        c = rng.randint(low=0, high=n_categories, size=n_samples)
        pd_dict[str(i)] = pd.Series(c, dtype=np.int64)

    df = pd.DataFrame(pd_dict)
    label = df.iloc[:, 0]
    df = df.iloc[:, 1:]
    for i in range(0, n_features):
        label += df.iloc[:, i]
    label += 1

    df = df.astype("category")
    categories = np.arange(0, n_categories)
    for col in df.columns:
        df[col] = df[col].cat.set_categories(categories)

    if onehot:
        return pd.get_dummies(df), label
    return df, label


def main() -> None:
    # Use builtin categorical data support

    # For scikit-learn interface, the input data should be pandas DataFrame or cudf
    # DataFrame with categorical features. If an numpy/cupy array is used instead, the
    # `feature_types` for `XGBRegressor` should be set accordingly.
    X, y = make_categorical(100, 10, 4, False)
    # Specify `enable_categorical` to True, also we use onehot-encoding-based split here
    # for demonstration. For details see the document of `max_cat_to_onehot`.
    reg = xgb.XGBRegressor(
        tree_method="hist", enable_categorical=True, max_cat_to_onehot=5, device="cuda"
    )
    reg.fit(X, y, eval_set=[(X, y)])

    # Pass in already encoded data
    X_enc, y_enc = make_categorical(100, 10, 4, True)
    reg_enc = xgb.XGBRegressor(tree_method="hist", device="cuda")
    reg_enc.fit(X_enc, y_enc, eval_set=[(X_enc, y_enc)])

    reg_results = np.array(reg.evals_result()["validation_0"]["rmse"])
    reg_enc_results = np.array(reg_enc.evals_result()["validation_0"]["rmse"])

    # Check that they have same results
    np.testing.assert_allclose(reg_results, reg_enc_results)

    # Convert to DMatrix for SHAP value
    booster: xgb.Booster = reg.get_booster()
    m = xgb.DMatrix(X, enable_categorical=True)  # specify categorical data support.
    SHAP = booster.predict(m, pred_contribs=True)
    margin = booster.predict(m, output_margin=True)
    np.testing.assert_allclose(
        np.sum(SHAP, axis=len(SHAP.shape) - 1), margin, rtol=1e-3
    )


if __name__ == "__main__":
    main()
# Out:
# [0]	validation_0-rmse:2.94171
# [1]	validation_0-rmse:2.40095
# [2]	validation_0-rmse:1.96121
# [3]	validation_0-rmse:1.61285
# [4]	validation_0-rmse:1.35854
# [5]	validation_0-rmse:1.12286
# [6]	validation_0-rmse:0.96789
# [7]	validation_0-rmse:0.79707
# [8]	validation_0-rmse:0.66201
# [9]	validation_0-rmse:0.55282
# [10]	validation_0-rmse:0.46038
# [11]	validation_0-rmse:0.38278
# [12]	validation_0-rmse:0.32840
# [13]	validation_0-rmse:0.27462
# [14]	validation_0-rmse:0.23398
# [15]	validation_0-rmse:0.19823
# [16]	validation_0-rmse:0.16984
# [17]	validation_0-rmse:0.14636
# [18]	validation_0-rmse:0.12447
# [19]	validation_0-rmse:0.10444
# [20]	validation_0-rmse:0.08984
# [21]	validation_0-rmse:0.07610
# [22]	validation_0-rmse:0.06622
# [23]	validation_0-rmse:0.05653
# [24]	validation_0-rmse:0.04906
# [25]	validation_0-rmse:0.04173
# [26]	validation_0-rmse:0.03550
# [27]	validation_0-rmse:0.03046
# [28]	validation_0-rmse:0.02585
# [29]	validation_0-rmse:0.02187
# [30]	validation_0-rmse:0.01863
# [31]	validation_0-rmse:0.01597
# [32]	validation_0-rmse:0.01361
# [33]	validation_0-rmse:0.01166
# [34]	validation_0-rmse:0.01041
# [35]	validation_0-rmse:0.00909
# [36]	validation_0-rmse:0.00780
# [37]	validation_0-rmse:0.00666
# [38]	validation_0-rmse:0.00569
# [39]	validation_0-rmse:0.00493
# [40]	validation_0-rmse:0.00426
# [41]	validation_0-rmse:0.00365
# [42]	validation_0-rmse:0.00314
# [43]	validation_0-rmse:0.00268
# [44]	validation_0-rmse:0.00233
# [45]	validation_0-rmse:0.00200
# [46]	validation_0-rmse:0.00170
# [47]	validation_0-rmse:0.00148
# [48]	validation_0-rmse:0.00130
# [49]	validation_0-rmse:0.00116
# [50]	validation_0-rmse:0.00100
# [51]	validation_0-rmse:0.00090
# [52]	validation_0-rmse:0.00082
# [53]	validation_0-rmse:0.00075
# [54]	validation_0-rmse:0.00075
# [55]	validation_0-rmse:0.00075
# [56]	validation_0-rmse:0.00075
# [57]	validation_0-rmse:0.00075
# [58]	validation_0-rmse:0.00075
# [59]	validation_0-rmse:0.00075
# [60]	validation_0-rmse:0.00075
# [61]	validation_0-rmse:0.00075
# [62]	validation_0-rmse:0.00075
# [63]	validation_0-rmse:0.00075
# [64]	validation_0-rmse:0.00075
# [65]	validation_0-rmse:0.00075
# [66]	validation_0-rmse:0.00075
# [67]	validation_0-rmse:0.00075
# [68]	validation_0-rmse:0.00075
# [69]	validation_0-rmse:0.00075
# [70]	validation_0-rmse:0.00075
# [71]	validation_0-rmse:0.00075
# [72]	validation_0-rmse:0.00075
# [73]	validation_0-rmse:0.00075
# [74]	validation_0-rmse:0.00075
# [75]	validation_0-rmse:0.00075
# [76]	validation_0-rmse:0.00075
# [77]	validation_0-rmse:0.00075
# [78]	validation_0-rmse:0.00075
# [79]	validation_0-rmse:0.00075
# [80]	validation_0-rmse:0.00075
# [81]	validation_0-rmse:0.00075
# [82]	validation_0-rmse:0.00075
# [83]	validation_0-rmse:0.00075
# [84]	validation_0-rmse:0.00075
# [85]	validation_0-rmse:0.00075
# [86]	validation_0-rmse:0.00075
# [87]	validation_0-rmse:0.00075
# [88]	validation_0-rmse:0.00075
# [89]	validation_0-rmse:0.00075
# [90]	validation_0-rmse:0.00075
# [91]	validation_0-rmse:0.00075
# [92]	validation_0-rmse:0.00075
# [93]	validation_0-rmse:0.00075
# [94]	validation_0-rmse:0.00075
# [95]	validation_0-rmse:0.00075
# [96]	validation_0-rmse:0.00075
# [97]	validation_0-rmse:0.00075
# [98]	validation_0-rmse:0.00075
# [99]	validation_0-rmse:0.00075
# [0]	validation_0-rmse:2.94171
# [1]	validation_0-rmse:2.40095
# [2]	validation_0-rmse:1.96121
# [3]	validation_0-rmse:1.61285
# [4]	validation_0-rmse:1.35854
# [5]	validation_0-rmse:1.12286
# [6]	validation_0-rmse:0.96789
# [7]	validation_0-rmse:0.79707
# [8]	validation_0-rmse:0.66201
# [9]	validation_0-rmse:0.55282
# [10]	validation_0-rmse:0.46038
# [11]	validation_0-rmse:0.38278
# [12]	validation_0-rmse:0.32840
# [13]	validation_0-rmse:0.27462
# [14]	validation_0-rmse:0.23398
# [15]	validation_0-rmse:0.19823
# [16]	validation_0-rmse:0.16984
# [17]	validation_0-rmse:0.14636
# [18]	validation_0-rmse:0.12447
# [19]	validation_0-rmse:0.10444
# [20]	validation_0-rmse:0.08984
# [21]	validation_0-rmse:0.07610
# [22]	validation_0-rmse:0.06622
# [23]	validation_0-rmse:0.05653
# [24]	validation_0-rmse:0.04906
# [25]	validation_0-rmse:0.04173
# [26]	validation_0-rmse:0.03550
# [27]	validation_0-rmse:0.03046
# [28]	validation_0-rmse:0.02585
# [29]	validation_0-rmse:0.02187
# [30]	validation_0-rmse:0.01863
# [31]	validation_0-rmse:0.01597
# [32]	validation_0-rmse:0.01361
# [33]	validation_0-rmse:0.01166
# [34]	validation_0-rmse:0.01041
# [35]	validation_0-rmse:0.00909
# [36]	validation_0-rmse:0.00780
# [37]	validation_0-rmse:0.00666
# [38]	validation_0-rmse:0.00569
# [39]	validation_0-rmse:0.00493
# [40]	validation_0-rmse:0.00426
# [41]	validation_0-rmse:0.00365
# [42]	validation_0-rmse:0.00314
# [43]	validation_0-rmse:0.00268
# [44]	validation_0-rmse:0.00233
# [45]	validation_0-rmse:0.00200
# [46]	validation_0-rmse:0.00170
# [47]	validation_0-rmse:0.00148
# [48]	validation_0-rmse:0.00130
# [49]	validation_0-rmse:0.00116
# [50]	validation_0-rmse:0.00100
# [51]	validation_0-rmse:0.00090
# [52]	validation_0-rmse:0.00082
# [53]	validation_0-rmse:0.00075
# [54]	validation_0-rmse:0.00075
# [55]	validation_0-rmse:0.00075
# [56]	validation_0-rmse:0.00075
# [57]	validation_0-rmse:0.00075
# [58]	validation_0-rmse:0.00075
# [59]	validation_0-rmse:0.00075
# [60]	validation_0-rmse:0.00075
# [61]	validation_0-rmse:0.00075
# [62]	validation_0-rmse:0.00075
# [63]	validation_0-rmse:0.00075
# [64]	validation_0-rmse:0.00075
# [65]	validation_0-rmse:0.00075
# [66]	validation_0-rmse:0.00075
# [67]	validation_0-rmse:0.00075
# [68]	validation_0-rmse:0.00075
# [69]	validation_0-rmse:0.00075
# [70]	validation_0-rmse:0.00075
# [71]	validation_0-rmse:0.00075
# [72]	validation_0-rmse:0.00075
# [73]	validation_0-rmse:0.00075
# [74]	validation_0-rmse:0.00075
# [75]	validation_0-rmse:0.00075
# [76]	validation_0-rmse:0.00075
# [77]	validation_0-rmse:0.00075
# [78]	validation_0-rmse:0.00075
# [79]	validation_0-rmse:0.00075
# [80]	validation_0-rmse:0.00075
# [81]	validation_0-rmse:0.00075
# [82]	validation_0-rmse:0.00075
# [83]	validation_0-rmse:0.00075
# [84]	validation_0-rmse:0.00075
# [85]	validation_0-rmse:0.00075
# [86]	validation_0-rmse:0.00075
# [87]	validation_0-rmse:0.00075
# [88]	validation_0-rmse:0.00075
# [89]	validation_0-rmse:0.00075
# [90]	validation_0-rmse:0.00075
# [91]	validation_0-rmse:0.00075
# [92]	validation_0-rmse:0.00075
# [93]	validation_0-rmse:0.00075
# [94]	validation_0-rmse:0.00075
# [95]	validation_0-rmse:0.00075
# [96]	validation_0-rmse:0.00075
# [97]	validation_0-rmse:0.00075
# [98]	validation_0-rmse:0.00075
# [99]	validation_0-rmse:0.00075
